# %%
# Importing Required Packages
import pandas as pd
import numpy as np
import random
import names

# %%
# Reading Three sheets from an excel file
orders = pd.read_excel(r'C:\Users\dukef\OneDrive\Documents\Nomura\Sample - Superstore.xlsx', sheet_name = "Orders")
returns = pd.read_excel(r'C:\Users\dukef\OneDrive\Documents\Nomura\Sample - Superstore.xlsx', sheet_name = "Returns")
people = pd.read_excel(r'C:\Users\dukef\OneDrive\Documents\Nomura\Sample - Superstore.xlsx', sheet_name = "People")

# %%
orders.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11  Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
# 1   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
returns.head(2)
# Out:
#   Returned        Order ID
# 0      Yes  CA-2018-100762
# 1      Yes  CA-2018-100762

# %%
people.head(2)
# Out:
#   Regional Manager Region
# 0  Sadie Pawthorne   West
# 1      Chuck Magee   East

# %%
a = set(range(5, 10))
b = set(range(7, 13))

# %%
print(a)
print(b)
# Out:
# {5, 6, 7, 8, 9}
# {7, 8, 9, 10, 11, 12}

# %%
# Inner Join
a.intersection(b)
# Out:
# {7, 8, 9}

# %%
# Full/Outer
a.union(b)
# Out:
# {5, 6, 7, 8, 9, 10, 11, 12}

# %%
# Creating a Dataframe with random Values
df = pd.DataFrame(np.random.randint(10, 100, (10, 5)), columns = list("ABCDE"))
df
# Out:
#     A   B   C   D   E
# 0  99  23  23  42  99
# 1  10  82  97  29  43
# 2  98  38  46  80  98
# 3  64  39  21  89  14
# 4  67  12  32  35  35
# 5  86  56  83  78  29
# 6  16  52  29  17  29
# 7  57  57  82  14  42
# 8  96  15  74  67  64
# 9  19  71  54  91  32

# %%
df1 = df.iloc[:3, :]
df2 = df.iloc[3:6, :]
df3 = df.iloc[6:, :]

# %%
df1
# Out:
#     A   B   C   D   E
# 0  75  55  26  35  89
# 1  99  10  46  91  37
# 2  61  42  28  93  61

# %%
df2
# Out:
#     A   B   C   D   E
# 3  52  87  53  14  68
# 4  30  96  82  48  55
# 5  54  99  53  64  83

# %%
df3
# Out:
#     A   B   C   D   E
# 6  46  89  30  72  54
# 7  30  94  33  33  69
# 8  72  53  46  23  27
# 9  39  62  19  98  67

# %%
pd.concat([df1, df2, df3])
# Out:
#     A   B   C   D   E
# 0  75  55  26  35  89
# 1  99  10  46  91  37
# 2  61  42  28  93  61
# 3  52  87  53  14  68
# 4  30  96  82  48  55
# 5  54  99  53  64  83
# 6  46  89  30  72  54
# 7  30  94  33  33  69
# 8  72  53  46  23  27
# 9  39  62  19  98  67

# %% [markdown]
# # Join and Merge

# %%
# Joins - Uses Index to merge dataframes
# Merge - Uses columns to merge dataframes

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df1 = orders.loc[:10,['Region', 'Sales', 'Profit']]
df1
# Out:
#    Region      Sales    Profit
# 0   South   261.9600   41.9136
# 1   South   731.9400  219.5820
# 2    West    14.6200    6.8714
# 3   South   957.5775 -383.0310
# 4   South    22.3680    2.5164
# 5    West    48.8600   14.1694
# 6    West     7.2800    1.9656
# 7    West   907.1520   90.7152
# 8    West    18.5040    5.7825
# 9    West   114.9000   34.4700
# 10   West  1706.1840   85.3092

# %%
df2 = people.copy()
df2
# Out:
#     Regional Manager   Region
# 0    Sadie Pawthorne     West
# 1        Chuck Magee     East
# 2  Roxanne Rodriguez  Central
# 3        Fred Suzuki    South

# %%
# Inner Join
pd.merge(df1, df2, on = 'Region', how = 'inner')
# Out:
#    Region      Sales    Profit Regional Manager
# 0   South   261.9600   41.9136      Fred Suzuki
# 1   South   731.9400  219.5820      Fred Suzuki
# 2   South   957.5775 -383.0310      Fred Suzuki
# 3   South    22.3680    2.5164      Fred Suzuki
# 4    West    14.6200    6.8714  Sadie Pawthorne
# 5    West    48.8600   14.1694  Sadie Pawthorne
# 6    West     7.2800    1.9656  Sadie Pawthorne
# 7    West   907.1520   90.7152  Sadie Pawthorne
# 8    West    18.5040    5.7825  Sadie Pawthorne
# 9    West   114.9000   34.4700  Sadie Pawthorne
# 10   West  1706.1840   85.3092  Sadie Pawthorne

# %%
# Left Join
pd.merge(df1, df2, on = 'Region', how = 'left')
# Out:
#    Region      Sales    Profit Regional Manager
# 0   South   261.9600   41.9136      Fred Suzuki
# 1   South   731.9400  219.5820      Fred Suzuki
# 2    West    14.6200    6.8714  Sadie Pawthorne
# 3   South   957.5775 -383.0310      Fred Suzuki
# 4   South    22.3680    2.5164      Fred Suzuki
# 5    West    48.8600   14.1694  Sadie Pawthorne
# 6    West     7.2800    1.9656  Sadie Pawthorne
# 7    West   907.1520   90.7152  Sadie Pawthorne
# 8    West    18.5040    5.7825  Sadie Pawthorne
# 9    West   114.9000   34.4700  Sadie Pawthorne
# 10   West  1706.1840   85.3092  Sadie Pawthorne

# %%
# Right Join
pd.merge(df1, df2, on = 'Region', how = 'right')
# Out:
#      Region      Sales    Profit   Regional Manager
# 0      West    14.6200    6.8714    Sadie Pawthorne
# 1      West    48.8600   14.1694    Sadie Pawthorne
# 2      West     7.2800    1.9656    Sadie Pawthorne
# 3      West   907.1520   90.7152    Sadie Pawthorne
# 4      West    18.5040    5.7825    Sadie Pawthorne
# 5      West   114.9000   34.4700    Sadie Pawthorne
# 6      West  1706.1840   85.3092    Sadie Pawthorne
# 7      East        NaN       NaN        Chuck Magee
# 8   Central        NaN       NaN  Roxanne Rodriguez
# 9     South   261.9600   41.9136        Fred Suzuki
# 10    South   731.9400  219.5820        Fred Suzuki
# 11    South   957.5775 -383.0310        Fred Suzuki
# 12    South    22.3680    2.5164        Fred Suzuki

# %%
# Right Join
pd.merge(df1, df2, on = 'Region', how = 'outer')
# Out:
#      Region      Sales    Profit   Regional Manager
# 0     South   261.9600   41.9136        Fred Suzuki
# 1     South   731.9400  219.5820        Fred Suzuki
# 2     South   957.5775 -383.0310        Fred Suzuki
# 3     South    22.3680    2.5164        Fred Suzuki
# 4      West    14.6200    6.8714    Sadie Pawthorne
# 5      West    48.8600   14.1694    Sadie Pawthorne
# 6      West     7.2800    1.9656    Sadie Pawthorne
# 7      West   907.1520   90.7152    Sadie Pawthorne
# 8      West    18.5040    5.7825    Sadie Pawthorne
# 9      West   114.9000   34.4700    Sadie Pawthorne
# 10     West  1706.1840   85.3092    Sadie Pawthorne
# 11     East        NaN       NaN        Chuck Magee
# 12  Central        NaN       NaN  Roxanne Rodriguez

# %%
# Creating a Copy of the existing Df and Modifying its column names
df3 = df2.copy()
df3.columns = ['Manager', 'Location']

# %%
df3
# Out:
#              Manager Location
# 0    Sadie Pawthorne     West
# 1        Chuck Magee     East
# 2  Roxanne Rodriguez  Central
# 3        Fred Suzuki    South

# %%
df1
# Out:
#    Region      Sales    Profit
# 0   South   261.9600   41.9136
# 1   South   731.9400  219.5820
# 2    West    14.6200    6.8714
# 3   South   957.5775 -383.0310
# 4   South    22.3680    2.5164
# 5    West    48.8600   14.1694
# 6    West     7.2800    1.9656
# 7    West   907.1520   90.7152
# 8    West    18.5040    5.7825
# 9    West   114.9000   34.4700
# 10   West  1706.1840   85.3092

# %%
# Merging DF's based on diff column names
pd.merge(df1, df3, left_on = 'Region', right_on = 'Location', how = 'inner')
# Out:
#    Region      Sales    Profit          Manager Location
# 0   South   261.9600   41.9136      Fred Suzuki    South
# 1   South   731.9400  219.5820      Fred Suzuki    South
# 2   South   957.5775 -383.0310      Fred Suzuki    South
# 3   South    22.3680    2.5164      Fred Suzuki    South
# 4    West    14.6200    6.8714  Sadie Pawthorne     West
# 5    West    48.8600   14.1694  Sadie Pawthorne     West
# 6    West     7.2800    1.9656  Sadie Pawthorne     West
# 7    West   907.1520   90.7152  Sadie Pawthorne     West
# 8    West    18.5040    5.7825  Sadie Pawthorne     West
# 9    West   114.9000   34.4700  Sadie Pawthorne     West
# 10   West  1706.1840   85.3092  Sadie Pawthorne     West

# %%
# Column Prefixes
pd.merge(df1, df3, left_on = 'Region', right_on = 'Location', how = 'inner')
# Out:
#    Region      Sales    Profit          Manager Location
# 0   South   261.9600   41.9136      Fred Suzuki    South
# 1   South   731.9400  219.5820      Fred Suzuki    South
# 2   South   957.5775 -383.0310      Fred Suzuki    South
# 3   South    22.3680    2.5164      Fred Suzuki    South
# 4    West    14.6200    6.8714  Sadie Pawthorne     West
# 5    West    48.8600   14.1694  Sadie Pawthorne     West
# 6    West     7.2800    1.9656  Sadie Pawthorne     West
# 7    West   907.1520   90.7152  Sadie Pawthorne     West
# 8    West    18.5040    5.7825  Sadie Pawthorne     West
# 9    West   114.9000   34.4700  Sadie Pawthorne     West
# 10   West  1706.1840   85.3092  Sadie Pawthorne     West

# %%
# Creating a Dataframe
df = pd.DataFrame({"Name": ['A', 'B'], "Values" : [1,2], 'New': [1,2]})
df
# Out:
#   Name  Values  New
# 0    A       1    1
# 1    B       2    2

# %%
# Creating a Dataframe
df1 = pd.DataFrame({"Name": ['C', 'B'], "Values" : [1,2], 'New' : [12,3]})
df1
# Out:
#   Name  Values  New
# 0    C       1   12
# 1    B       2    3

# %%
# Merging a DataFrame with Suffixes
pd.merge(df, df1, on = "Name", suffixes = ('_Left', '_Right'))
# Out:
#   Name  Values_Left  New_Left  Values_Right  New_Right
# 0    B            2         2             2          3

# %%
# pd.merge(df, df1, on = "Name", suffixes = (None, None))

# %% [markdown]
# # Joins

# %%
df1
# Out:
#    Region      Sales    Profit
# 0   South   261.9600   41.9136
# 1   South   731.9400  219.5820
# 2    West    14.6200    6.8714
# 3   South   957.5775 -383.0310
# 4   South    22.3680    2.5164
# 5    West    48.8600   14.1694
# 6    West     7.2800    1.9656
# 7    West   907.1520   90.7152
# 8    West    18.5040    5.7825
# 9    West   114.9000   34.4700
# 10   West  1706.1840   85.3092

# %%
df2
# Out:
#     Regional Manager   Region
# 0    Sadie Pawthorne     West
# 1        Chuck Magee     East
# 2  Roxanne Rodriguez  Central
# 3        Fred Suzuki    South

# %%
# Performing Joins on two tables
df1.join(df2, lsuffix = '_left', rsuffix = '_right')
# Out:
#    Region_left      Sales    Profit   Regional Manager Region_right
# 0        South   261.9600   41.9136    Sadie Pawthorne         West
# 1        South   731.9400  219.5820        Chuck Magee         East
# 2         West    14.6200    6.8714  Roxanne Rodriguez      Central
# 3        South   957.5775 -383.0310        Fred Suzuki        South
# 4        South    22.3680    2.5164                NaN          NaN
# 5         West    48.8600   14.1694                NaN          NaN
# 6         West     7.2800    1.9656                NaN          NaN
# 7         West   907.1520   90.7152                NaN          NaN
# 8         West    18.5040    5.7825                NaN          NaN
# 9         West   114.9000   34.4700                NaN          NaN
# 10        West  1706.1840   85.3092                NaN          NaN

# %%
# Performing Joins on two tables
df1.join(df2, lsuffix = '_left', rsuffix = '_right')
# Out:
#    Region_left      Sales    Profit   Regional Manager Region_right
# 0        South   261.9600   41.9136    Sadie Pawthorne         West
# 1        South   731.9400  219.5820        Chuck Magee         East
# 2         West    14.6200    6.8714  Roxanne Rodriguez      Central
# 3        South   957.5775 -383.0310        Fred Suzuki        South
# 4        South    22.3680    2.5164                NaN          NaN
# 5         West    48.8600   14.1694                NaN          NaN
# 6         West     7.2800    1.9656                NaN          NaN
# 7         West   907.1520   90.7152                NaN          NaN
# 8         West    18.5040    5.7825                NaN          NaN
# 9         West   114.9000   34.4700                NaN          NaN
# 10        West  1706.1840   85.3092                NaN          NaN

# %%
# Summarizing Data using Pivots
df1.pivot_table(values = 'Profit', index = 'Region', aggfunc = 'sum')
# Out:
#           Profit
# Region
# South  -119.0190
# West    239.2833

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# Summarizing Data using Pivots
orders.pivot_table(values = 'Profit', index = 'Region', columns = 'Category', aggfunc = 'mean')
# Out:
# Category  Furniture  Office Supplies  Technology
# Region
# Central   -5.968918         6.244712   80.231981
# East       5.068496        23.957114   88.714084
# South     20.395199        20.086827   68.231506
# West      16.272914        27.733183   73.962687

# %%
# Apply Function - Applies a logic on each and every value in a column
logic = lambda x : x * 2
df1['Profit'] = df['Profit'].apply(logic)

# %%
df1
# Out:
#    Region      Sales    Profit
# 0   South   261.9600   83.8272
# 1   South   731.9400  439.1640
# 2    West    14.6200   13.7428
# 3   South   957.5775 -766.0620
# 4   South    22.3680    5.0328
# 5    West    48.8600       NaN
# 6    West     7.2800       NaN
# 7    West   907.1520       NaN
# 8    West    18.5040       NaN
# 9    West   114.9000       NaN
# 10   West  1706.1840       NaN

# %% [markdown]
# #### Lambda - Filter, map and Reduce

# %%
import matplotlib.pyplot as plt

# %%
# Creating a List
a = list(range(1, 15, 3))
a
# Out:
# [1, 4, 7, 10, 13]

# %%
# Creating a List randomly using Comprehensions
b = [random.randint(10, 100) for i in range(5)]
b
# Out:
# [97, 81, 28, 52, 15]

# %%
# Line Chart
plt.plot(a, b) # X and Y Axis

# %%
# Line Chart without Object info
plt.plot(a, b);

# %%
# Formatting the chart
plt.plot(a, b)
plt.title("Relationship Between A and B")
plt.xlabel('A')
plt.ylabel("B");

# %%
# Another way to suppress the Object Properties
plt.plot(a, b)
plt.title("Relationship Between A and B")
plt.xlabel('A')
plt.ylabel("B");
plt.show()

# %%
# Saving the visual as an Image
plt.plot(a, b)
plt.title("Relationship Between A and B")
plt.xlabel('A')
plt.ylabel("B")
plt.savefig('A vs B.jpg') #.png, .jpg, jpeg

# %%
# Saving the visual as an Image in a diff location
plt.plot(a, b)
plt.title("Relationship Between A and B")
plt.xlabel('A')
plt.ylabel("B")
plt.savefig(r'C:\Users\dukef\OneDrive\Documents\Teaching\Tables\A vs B.jpg') #.png, .jpg, jpeg

# %%
c = [random.randint(10, 100) for i in range(5)]
c
# Out:
# [100, 68, 15, 94, 53]

# %%
plt.plot(a, b)
plt.plot(a, c);

# %%
# Adding Legend
plt.plot(a, b)
plt.plot(a, c)
plt.title("Relationship for A vs B and C")
plt.xlabel('A')
plt.ylabel("B and C")
plt.legend(labels = ['B', 'C']);

# %%
# Adding Legend
plt.plot(a, b)
plt.plot(a, c)
plt.title("Relationship for A vs B and C")
plt.xlabel('A')
plt.ylabel("B and C")
plt.legend(labels = ['B', 'C'], loc = 'lower right'); # Upper Left, upper right, lower left and lower right
