# %%
import pandas as pd
import numpy as np
import random
import names

# %% [markdown]
# # Series

# %%
s = pd.Series([1,2,"Python", True, 12.5])
s
# Out:
# 0         1
# 1         2
# 2    Python
# 3      True
# 4      12.5
# dtype: object

# %%
s[2]
# Out:
# 'Python'

# %%
s[4]
# Out:
# 12.5

# %%
l = list(range(10, 15))
l
# Out:
# [10, 11, 12, 13, 14]

# %%
s.index = l
s
# Out:
# 10         1
# 11         2
# 12    Python
# 13      True
# 14      12.5
# dtype: object

# %%
list("ABCDE")
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
s = pd.Series([1,2,"Python", True, 12.5], index = list("ABCDE"))
s
# Out:
# A         1
# B         2
# C    Python
# D      True
# E      12.5
# dtype: object

# %%
s[0] = "Lalith"
s
# Out:
# A    Lalith
# B         2
# C    Python
# D      True
# E      12.5
# dtype: object

# %%
s = pd.Series([1,2,"Python", True, 12.5], index = list("ABCDEF"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1952/1383842290.py in <module>
# ----> 1 s = pd.Series([1,2,"Python", True, 12.5], index = list("ABCDEF"))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     428                 index = ibase.default_index(len(data))
#     429             elif is_list_like(data):
# --> 430                 com.require_length_match(data, index)
#     431
#     432             # create/copy the manager
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (5) does not match length of index (6)

# %%
s
# Out:
# A    Lalith
# B         2
# C    Python
# D      True
# E      12.5
# dtype: object

# %%
s['A']
# Out:
# 'Lalith'

# %%
s['E']
# Out:
# 12.5

# %% [markdown]
# # DataFrame

# %%
df = pd.DataFrame({"Name" : ['A', 'B', 'C', 'D'], 'Marks' : [10, 20, 30, 40]})
df
# Out:
#   Name  Marks
# 0    A     10
# 1    B     20
# 2    C     30
# 3    D     40

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
np.random.randint(10, 100, (10, 5))
# Out:
# array([[62, 34, 92, 77, 83],
#        [46, 48, 98, 53, 76],
#        [38, 78, 23, 79, 55],
#        [71, 55, 47, 94, 33],
#        [69, 70, 53, 73, 62],
#        [58, 35, 50, 13, 71],
#        [93, 14, 25, 53, 37],
#        [70, 85, 71, 67, 77],
#        [85, 58, 67, 50, 64],
#        [18, 30, 55, 82, 74]])

# %%
df = pd.DataFrame(np.random.randint(10, 100, (10, 5)))
df
# Out:
#     0   1   2   3   4
# 0  70  19  49  25  43
# 1  41  40  96  76  71
# 2  54  16  65  78  35
# 3  76  70  88  11  21
# 4  53  51  66  14  41
# 5  72  21  91  28  17
# 6  60  76  15  44  26
# 7  16  84  48  94  70
# 8  35  48  48  24  29
# 9  47  92  17  93  99

# %%
df = pd.DataFrame(np.random.randint(10, 100, (10, 4)), columns = ['Apple', 'MS', 'Google', 'Amazon'])
df
# Out:
#    Apple  MS  Google  Amazon
# 0     80  84      12      57
# 1     13  22      89      85
# 2     60  66      21      15
# 3     99  89      32      73
# 4     31  69      23      61
# 5     83  72      86      34
# 6     34  18      67      99
# 7     21  84      47      25
# 8     16  35      42      58
# 9     10  39      12      43

# %%
dates = pd.date_range(start = "2022-02-01", periods = 10, freq = 'd')
dates
# Out:
# DatetimeIndex(['2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04',
#                '2022-02-05', '2022-02-06', '2022-02-07', '2022-02-08',
#                '2022-02-09', '2022-02-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
months = pd.date_range(start = "2022-02-01", periods = 10, freq = 'm')
months
# Out:
# DatetimeIndex(['2022-02-28', '2022-03-31', '2022-04-30', '2022-05-31',
#                '2022-06-30', '2022-07-31', '2022-08-31', '2022-09-30',
#                '2022-10-31', '2022-11-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
years = pd.date_range(start = "2022-02-01", periods = 10, freq = 'y')
years
# Out:
# DatetimeIndex(['2022-12-31', '2023-12-31', '2024-12-31', '2025-12-31',
#                '2026-12-31', '2027-12-31', '2028-12-31', '2029-12-31',
#                '2030-12-31', '2031-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
weeks = pd.date_range(start = "2022-02-01", periods = 10, freq = 'w')
weeks
# Out:
# DatetimeIndex(['2022-02-06', '2022-02-13', '2022-02-20', '2022-02-27',
#                '2022-03-06', '2022-03-13', '2022-03-20', '2022-03-27',
#                '2022-04-03', '2022-04-10'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
# ...

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
weeks = pd.date_range(start = "2022-02-01", periods = 10, freq = 'w-sat')
weeks
# Out:
# DatetimeIndex(['2022-02-05', '2022-02-12', '2022-02-19', '2022-02-26',
#                '2022-03-05', '2022-03-12', '2022-03-19', '2022-03-26',
#                '2022-04-02', '2022-04-09'],
#               dtype='datetime64[ns]', freq='W-SAT')

# %%
df
# Out:
#    Apple  MS  Google  Amazon
# 0     80  84      12      57
# 1     13  22      89      85
# 2     60  66      21      15
# 3     99  89      32      73
# 4     31  69      23      61
# 5     83  72      86      34
# 6     34  18      67      99
# 7     21  84      47      25
# 8     16  35      42      58
# 9     10  39      12      43

# %%
dates
# Out:
# DatetimeIndex(['2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04',
#                '2022-02-05', '2022-02-06', '2022-02-07', '2022-02-08',
#                '2022-02-09', '2022-02-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.index = dates
df
# Out:
#             Apple  MS  Google  Amazon
# 2022-02-01     80  84      12      57
# 2022-02-02     13  22      89      85
# 2022-02-03     60  66      21      15
# 2022-02-04     99  89      32      73
# 2022-02-05     31  69      23      61
# 2022-02-06     83  72      86      34
# 2022-02-07     34  18      67      99
# 2022-02-08     21  84      47      25
# 2022-02-09     16  35      42      58
# 2022-02-10     10  39      12      43

# %%
names = [names.get_first_name() for i in range(10)]
names
# Out:
# ['Robert',
#  'Charles',
#  'Bobby',
#  'Shelley',
#  'Ricky',
#  'Mary',
#  'Wesley',
#  'Isadora',
#  'Adam',
#  'Shelley']

# %%
eng = [random.randint(35, 100) for i in range(10)]
eng
# Out:
# [79, 63, 42, 83, 37, 54, 92, 87, 83, 79]

# %%
maths = [random.randint(35, 100) for i in range(10)]
maths
# Out:
# [91, 60, 39, 97, 58, 47, 60, 54, 48, 45]

# %%
phy = [random.randint(35, 100) for i in range(10)]
phy
# Out:
# [60, 77, 56, 87, 65, 67, 37, 73, 96, 85]

# %%
df = pd.DataFrame({'English' : eng, 'Maths' : maths, "Physics" : phy}, index = names)
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65
# Mary          54     47       67
# Wesley        92     60       37
# Isadora       87     54       73
# Adam          83     48       96
# Shelley       79     45       85

# %% [markdown]
# # Accessing Values from a DataFrame

# %%
df1 = pd.DataFrame({'English' : eng, 'Maths' : maths, "Physics" : phy})[:5]
df1
# Out:
#    English  Maths  Physics
# 0       79     91       60
# 1       63     60       77
# 2       42     39       56
# 3       83     97       87
# 4       37     58       65

# %%
df = df[:5]
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df1
# Out:
#    English  Maths  Physics
# 0       79     91       60
# 1       63     60       77
# 2       42     39       56
# 3       83     97       87
# 4       37     58       65

# %%
df1['English']
# Out:
# 0    79
# 1    63
# 2    42
# 3    83
# 4    37
# Name: English, dtype: int64

# %%
df1['Maths']
# Out:
# 0    91
# 1    60
# 2    39
# 3    97
# 4    58
# Name: Maths, dtype: int64

# %%
df1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1[:, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1952/2143797627.py in <module>
# ----> 1 df1[:, :]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
df1
# Out:
#    English  Maths  Physics
# 0       79     91       60
# 1       63     60       77
# 2       42     39       56
# 3       83     97       87
# 4       37     58       65

# %%
df1.loc[:, :]
# Out:
#    English  Maths  Physics
# 0       79     91       60
# 1       63     60       77
# 2       42     39       56
# 3       83     97       87
# 4       37     58       65

# %%
df1.loc[1:4, 'English':'Physics']
# Out:
#    English  Maths  Physics
# 1       63     60       77
# 2       42     39       56
# 3       83     97       87
# 4       37     58       65

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df.loc[2:, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1952/4012600250.py in <module>
# ----> 1 df.loc[2:, :]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df.loc["Robert":"Bobby", "Maths":]
# Out:
#          Maths  Physics
# Robert      91       60
# Charles     60       77
# Bobby       39       56

# %%
df.loc[['Robert', 'Bobby', 'Ricky'], :]
# Out:
#         English  Maths  Physics
# Robert       79     91       60
# Bobby        42     39       56
# Ricky        37     58       65

# %%
df.loc[['Robert', 'Bobby', 'Ricky'], ['English', 'Physics']]
# Out:
#         English  Physics
# Robert       79       60
# Bobby        42       56
# Ricky        37       65

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %% [markdown]
# # Iloc

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df.iloc[:, :]
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df.iloc[:2, 1:]
# Out:
#          Maths  Physics
# Robert      91       60
# Charles     60       77

# %%
df.iloc[2:, :2]
# Out:
#          English  Maths
# Bobby         42     39
# Shelley       83     97
# Ricky         37     58

# %%
df.iloc['Robert':, "English"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1425         else:
# -> 1426             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1427
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1952/2388629476.py in <module>
# ...

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df.iloc[[0, 2, 4], [0, 2]]
# Out:
#         English  Physics
# Robert       79       60
# Bobby        42       56
# Ricky        37       65

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df.iloc[[0,2,4], :]
# Out:
#         English  Maths  Physics
# Robert       79     91       60
# Bobby        42     39       56
# Ricky        37     58       65

# %%
df['English']
# Out:
# Robert     79
# Charles    63
# Bobby      42
# Shelley    83
# Ricky      37
# Name: English, dtype: int64

# %%
df
# Out:
#          English  Maths  Physics
# Robert        79     91       60
# Charles       63     60       77
# Bobby         42     39       56
# Shelley       83     97       87
# Ricky         37     58       65

# %%
df['Total'] = df['English'] + df['Maths'] + df['Physics']
df
# Out:
# C:\Users\dukef\AppData\Local\Temp/ipykernel_1952/1601637424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = df['English'] + df['Maths'] + df['Physics']
#          English  Maths  Physics  Total
# Robert        79     91       60    230
# Charles       63     60       77    200
# Bobby         42     39       56    137
# Shelley       83     97       87    267
# Ricky         37     58       65    160

# %%
df['Average'] = round(df['Total'] / 3, 2)
df
# Out:
# C:\Users\dukef\AppData\Local\Temp/ipykernel_1952/407701152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average'] = round(df['Total'] / 3, 2)
#          English  Maths  Physics  Total  Average
# Robert        79     91       60    230    76.67
# Charles       63     60       77    200    66.67
# Bobby         42     39       56    137    45.67
# Shelley       83     97       87    267    89.00
# Ricky         37     58       65    160    53.33

# %% [markdown]
# # Boolean Indexing

# %%
df
# Out:
#          English  Maths  Physics  Total  Average
# Robert        79     91       60    230    76.67
# Charles       63     60       77    200    66.67
# Bobby         42     39       56    137    45.67
# Shelley       83     97       87    267    89.00
# Ricky         37     58       65    160    53.33

# %%
df['Total'] < 200
# Out:
# Robert     False
# Charles    False
# Bobby       True
# Shelley    False
# Ricky       True
# Name: Total, dtype: bool

# %%
df[df['Total'] < 200]
# Out:
#        English  Maths  Physics  Total  Average
# Bobby       42     39       56    137    45.67
# Ricky       37     58       65    160    53.33

# %%
s = df[df['Total'] < 200]['Total']
s
# Out:
# Bobby    137
# Ricky    160
# Name: Total, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
df[df['Total'] < 200][['Total', 'Average']]
# Out:
#        Total  Average
# Bobby    137    45.67
# Ricky    160    53.33

# %%
df[df['Total'] < 200][['Total', 'Physics']]
# Out:
#        Total  Physics
# Bobby    137       56
# Ricky    160       65

# %%
pd.DataFrame(df[df['Total'] < 200]['Total'])
# Out:
#        Total
# Bobby    137
# Ricky    160

# %% [markdown]
# # Operations in Pandas

# %%
df
# Out:
#          English  Maths  Physics  Total  Average
# Robert        79     91       60    230    76.67
# Charles       63     60       77    200    66.67
# Bobby         42     39       56    137    45.67
# Shelley       83     97       87    267    89.00
# Ricky         37     58       65    160    53.33

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dukef\\Python Works\\Weekday'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Day 1 - Numpy.ipynb',
#  'Day 2 - Numpy.ipynb',
#  'Day 3 - Pandas.ipynb',
#  'Sample - Superstore.csv']

# %%
df = pd.read_csv('Sample - Superstore.csv', encoding = 'latin') #Use Encoding only when you face this error - UnicodeDecodeError
df.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520
# 1       2  CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
# 1   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel(r'C:\Users\dukef\OneDrive\Documents\Nomura\Sample - Superstore.xlsx') # r - Raw String
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11  Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
# 1   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]
